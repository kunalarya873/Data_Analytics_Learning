# %% [markdown]
# # Strings

# %% [markdown]
# A string is a sequence of characters.
#
# Computers do not deal with characters, they deal with numbers (binary). Even though you may see characters on your screen, internally it is stored and manipulated as a combination of 0's and 1's.
#
# This conversion of character to a number is called encoding, and the reverse process is decoding. ASCII and Unicode are some of the popular encoding used.
#
# In Python, string is a sequence of Unicode character.

# %% [markdown]
# In Python, string is an immutable sequence data type. It is the sequence of Unicode characters wrapped inside single, double, or triple quotes.
#
# The followings are valid string literals in Python.
#
# 'This is a string in Python' # string in single quotes
#
# "This is a string in Python" # string in double quotes
#
# '''This is a string in Python''' # string in triple quotes
#
# """This is a string in Python""" # string in triple double-quotes

# %%
##A string literal can be assigned to a variable, as shown below.

str1='This is a string in Python' 
print(str1)
str2="This is a string" 
print(str2)
# Out:
# This is a string in Python
# This is a string

# %% [markdown]
# Multi-line strings must be embed in triple quotes, as shown below.

# %%
str1='''This is 
the first
Multi-line string.
'''
print(str1)

str2="""This is
the second
Multi-line
string."""
print(str2)
# Out:
# This is
# the first
# Multi-line string.
#
# This is
# the second
# Multi-line
# string.

# %% [markdown]
# # How to create a string?

# %% [markdown]
# Strings can be created by enclosing characters inside a single quote or double quotes.
#
# Even triple quotes can be used in Python but generally used to represent multiline strings and docstrings.

# %%
aString = 'Hello World'

print(aString)

aString = 'Hello World'
print(aString)


aString = '''Hello World'''
print(aString)
# Out:
# Hello World
# Hello World
# Hello World

# %% [markdown]
# # How to access characters in a string?

# %% [markdown]
# We can access individual characters using indexing and a range of characters using slicing.
#
# Index starts from 0.
#
# Trying to access a character out of index range will raise an IndexError.
#
# The index must be an integer. We can't use float or other types, this will result into TypeError.
#
# Python allows negative indexing for its sequences.

# %%
aString = 'Hello World'

#print first Character
print(aString[0])

#print last character using negative indexing
print(aString[-1])

#slicing 2nd to 5th character
print(aString[2:5])
# Out:
# H
# d
# llo

# %% [markdown]
# If we try to access index out of the range or use decimal number, we will get errors.

# %%
print(aString[15])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-24aeb289f256> in <module>
# ----> 1 print(aString[15])
#
# IndexError: string index out of range

# %%
print(aString[1.5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-0d2537294a02> in <module>
# ----> 1 print(aString[1.5])
#
# TypeError: string indices must be integers

# %% [markdown]
# # How to change or delete a string ?

# %% [markdown]
# Strings are immutable. This means that elements of a string cannot be changed once it has been assigned.
#
# We can simply reassign different strings to the same name.

# %%
aString = 'Hello World'
aString[4] = 's' # strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2240e48aa649> in <module>
#       1 aString = 'Hello World'
# ----> 2 aString[4] = 's' # strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# We cannot delete or remove characters from a string. But deleting the string entirely is possible using the keyword       del.

# %%
del aString # delete complete string

# %%
print(aString)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d255c7b5955d> in <module>
# ----> 1 print(aString)
#
# NameError: name 'aString' is not defined

# %% [markdown]
# # String Operations

# %% [markdown]
# # Concatenation

# %% [markdown]
# Joining of two or more strings into a single one is called concatenation.
#
# The + operator does this in Python. Simply writing two string literals together also concatenates them.
#
# The * operator can be used to repeat the string for a given number of times.

# %%
aString1 = "Hello "
aString2 = "India"

#concatenation of 2 strings
print(aString1 + aString2)

#repeat string n times
print(aString1 * 3)
# Out:
# Hello India
# Hello Hello Hello

# %% [markdown]
# # Iterating Through String

# %%
count = 0
for l in "Hello World ocean":
    if l == 'e':
        count += 1
print(count, ' World is a Great Place')
# Out:
# 2  World is a Great Place

# %% [markdown]
# # String Membership Test

# %%
print('y' in 'Hello World') #in operator to test membership
# Out:
# False

# %%
print('od' in 'Hello World')
# Out:
# False

# %% [markdown]
# # String Methods

# %% [markdown]
#     Some of the commonly used methods are lower(), upper(), join(), split(), find(), replace() etc

# %%
"Hello".lower()
# Out:
# 'hello'

# %%
"Hello".upper()
# Out:
# 'HELLO'

# %%
"This will split all words in a list".split()
# Out:
# ['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list']

# %%
' '.join(['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list'])
# Out:
# 'This will split all words in a list'

# %%
"Good Morning".find("Mo")
# Out:
# 5

# %%
s1 = "Bad morning"

s2 = s1.replace("Bad", "Good")

print(s1)
print(s2)
# Out:
# Bad morning
# Good morning

# %% [markdown]
# # Python Program to Check where a String is Palindrome or not ?

# %%
aString = "DeedL"

#convert entire string to either lower or upper
aString = aString.lower()

#reverse string
revString = reversed(aString)


#check if the string is equal to its reverse
if list(aString) == list(revString):
    print("Given String is palindrome")
else:
    print("Given String is not palindrome")
# Out:
# Given String is not palindrome

# %% [markdown]
# # Python Program to Sort Words in Alphabetic Order?

# %%
aString = "a village on the West coast of Scotland"

#breakdown the string into list of words
allWords = aString.split()

#sort the list
allWords.sort()

#print Sorted words are
for word in allWords:
    print(word)
# Out:
# Scotland
# West
# a
# coast
# of
# on
# the
# village
